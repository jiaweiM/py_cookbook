# %% [markdown]
# ## <font color='red'><h4 align="center">1. 创建数据</f4></font>

# %% [markdown]
# #### 2) 通过 ndarray/list dict 创建
#
# 所有的 ndarrays 长度必须相同，如果传入 index 参数，则必须和 ndarray 长度相同。

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)

# %%
# 通过字典定义,键值对应标题，以最长的值作为行数，不足的重复填充
df2 = pd.DataFrame({'A':1.,
                    'B': pd.Timestamp('20170706'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3]*4, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'foo'})
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 输出的数值列的相关信息
df2.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### <font color='blue'>读取 csv 文件</font>

# %%
df = pd.read_csv("data/weather_data.csv")
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#       <td>4</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1/6/2017</td>
#       <td>31</td>
#       <td>2</td>
#       <td>Sunny</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.shape
# Out:
# (6, 4)

# %% [markdown]
# ## <font color="red"><h4 align="center">2. 数据操作</h4></font>
#
# 主要集中在 Series 和 DataFrame 上，它们比 Panel 使用更为普遍。
#
# Python 和 NumPy 的索引操作 [] 使用很方便，不过因为提前不知道数据的类型，所以使用这种标准操作存在优化限制。所以，请尽量使用 Pandas 独有的方法。
#
# Pandas 目前支持三种多维索引方法：
# - **.loc**, 基于 label
# - **.iloc**, 基于 position [0, length-1]

# %% [markdown]
# ### <font color="blue">2.1 使用 [ ] 选择数据</font>
#
# <table border="1">
# <tr>
# <th>数据类型</th>
# <th>选择语法</th>
# <th>返回值类型</th>
# </tr>
# <tr>
# <td>Series</td>
# <td>series[label]</td>
# <td>scalar value</td>
# </tr>
# <tr>
# <td>DataFrame</td>
# <td>frame[colname]</td>
# <td>和colname对应的Series</td>
# </tr>
# <tr>
# <td>Panel</td>
# <td>panel[itemname]</td>
# <td>和itemname对应的 DataFrame</td>
# </tr>
# </table>

# %% [markdown]
# 首先，定义我们需要的数据。
#
# 由于 Pandas 决定放弃Panel 的使用，所以下面不演示 Panel。

# %%
dates = pd.date_range('7/6/2017', periods=8)
# index 对应行，columns定义列，即标题
df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>-0.850651</td>
#       <td>-0.477734</td>
#       <td>-1.588885</td>
#       <td>0.245086</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>0.648335</td>
#       <td>-1.008562</td>
#       <td>0.986980</td>
#       <td>1.136734</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.570197</td>
#       <td>0.545597</td>
#       <td>-0.815030</td>
#       <td>1.584542</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>-1.673372</td>
#       <td>-0.673596</td>
#       <td>-0.711874</td>
#       <td>-0.976931</td>
#     </tr>
#     <tr>
#       <th>2017-07-10</th>
#       <td>-1.401200</td>
#       <td>0.677008</td>
#       <td>-2.046262</td>
#       <td>-1.787886</td>
#     </tr>
#     <tr>
#       <th>2017-07-11</th>
#       <td>-0.704555</td>
#       <td>1.036348</td>
#       <td>-1.477565</td>
#       <td>0.945378</td>
#     </tr>
#     <tr>
#       <th>2017-07-12</th>
#       <td>0.173839</td>
#       <td>-0.232074</td>
#       <td>-0.030759</td>
#       <td>0.707334</td>
#     </tr>
#     <tr>
#       <th>2017-07-13</th>
#       <td>0.419350</td>
#       <td>1.062200</td>
#       <td>-0.554513</td>
#       <td>-0.217730</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 获得 'A' 这一列
s = df['A']
s
# Out:
# 2017-07-06   -0.850651
# 2017-07-07    0.648335
# 2017-07-08    0.570197
# 2017-07-09   -1.673372
# 2017-07-10   -1.401200
# 2017-07-11   -0.704555
# 2017-07-12    0.173839
# 2017-07-13    0.419350
# Freq: D, Name: A, dtype: float64

# %%
# 和 df['A'] 效果相同
df.A
# Out:
# 2017-07-06   -0.850651
# 2017-07-07    0.648335
# 2017-07-08    0.570197
# 2017-07-09   -1.673372
# 2017-07-10   -1.401200
# 2017-07-11   -0.704555
# 2017-07-12    0.173839
# 2017-07-13    0.419350
# Freq: D, Name: A, dtype: float64

# %%
# 获得第 6 个值
s[dates[5]]
# Out:
# -0.70455509146770023

# %%
# 将 A 和 B两列交换
df[['B', 'A']] = df[['A', 'B']]

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>-0.477734</td>
#       <td>-0.850651</td>
#       <td>-1.588885</td>
#       <td>0.245086</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>-1.008562</td>
#       <td>0.648335</td>
#       <td>0.986980</td>
#       <td>1.136734</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.545597</td>
#       <td>0.570197</td>
#       <td>-0.815030</td>
#       <td>1.584542</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>-0.673596</td>
#       <td>-1.673372</td>
#       <td>-0.711874</td>
#       <td>-0.976931</td>
#     </tr>
#     <tr>
#       <th>2017-07-10</th>
#       <td>0.677008</td>
#       <td>-1.401200</td>
#       <td>-2.046262</td>
#       <td>-1.787886</td>
#     </tr>
#     <tr>
#       <th>2017-07-11</th>
#       <td>1.036348</td>
#       <td>-0.704555</td>
#       <td>-1.477565</td>
#       <td>0.945378</td>
#     </tr>
#     <tr>
#       <th>2017-07-12</th>
#       <td>-0.232074</td>
#       <td>0.173839</td>
#       <td>-0.030759</td>
#       <td>0.707334</td>
#     </tr>
#     <tr>
#       <th>2017-07-13</th>
#       <td>1.062200</td>
#       <td>0.419350</td>
#       <td>-0.554513</td>
#       <td>-0.217730</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 选择 A 和 B 这两列
df[['A', 'B']]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>-0.850651</td>
#       <td>-0.477734</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>0.648335</td>
#       <td>-1.008562</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.570197</td>
#       <td>0.545597</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>-1.673372</td>
#       <td>-0.673596</td>
#     </tr>
#     <tr>
#       <th>2017-07-10</th>
#       <td>-1.401200</td>
#       <td>0.677008</td>
#     </tr>
#     <tr>
#       <th>2017-07-11</th>
#       <td>-0.704555</td>
#       <td>1.036348</td>
#     </tr>
#     <tr>
#       <th>2017-07-12</th>
#       <td>0.173839</td>
#       <td>-0.232074</td>
#     </tr>
#     <tr>
#       <th>2017-07-13</th>
#       <td>0.419350</td>
#       <td>1.062200</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# 最好的切片选择是使用 **.iloc** 方法，不过使用 [] 也可以

# %%
# 获得s的前5项
s[:5]
# Out:
# 2017-07-06   -0.850651
# 2017-07-07    0.648335
# 2017-07-08    0.570197
# 2017-07-09   -1.673372
# 2017-07-10   -1.401200
# Freq: D, Name: A, dtype: float64

# %%
# 每两个选一个，即隔一个选一个
s[::2]
# Out:
# 2017-07-06   -0.850651
# 2017-07-08    0.570197
# 2017-07-10   -1.401200
# 2017-07-12    0.173839
# Freq: 2D, Name: A, dtype: float64

# %%
# 倒着选择全部
s[::-1]
# Out:
# 2017-07-13    0.419350
# 2017-07-12    0.173839
# 2017-07-11   -0.704555
# 2017-07-10   -1.401200
# 2017-07-09   -1.673372
# 2017-07-08    0.570197
# 2017-07-07    0.648335
# 2017-07-06   -0.850651
# Freq: -1D, Name: A, dtype: float64

# %%
# 复制s，将s2的前5项设置为0
s2 = s.copy()
s2[:5] = 0

# %%
s2
# Out:
# 2017-07-06    0.000000
# 2017-07-07    0.000000
# 2017-07-08    0.000000
# 2017-07-09    0.000000
# 2017-07-10    0.000000
# 2017-07-11   -0.704555
# 2017-07-12    0.173839
# 2017-07-13    0.419350
# Freq: D, Name: A, dtype: float64

# %%
# 选择 1-2 这两行
df[1:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-07</th>
#       <td>0.648335</td>
#       <td>-1.008562</td>
#       <td>0.98698</td>
#       <td>1.136734</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.570197</td>
#       <td>0.545597</td>
#       <td>-0.81503</td>
#       <td>1.584542</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 选择 DataFrame 的前3行
df[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>-0.850651</td>
#       <td>-0.477734</td>
#       <td>-1.588885</td>
#       <td>0.245086</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>0.648335</td>
#       <td>-1.008562</td>
#       <td>0.986980</td>
#       <td>1.136734</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.570197</td>
#       <td>0.545597</td>
#       <td>-0.815030</td>
#       <td>1.584542</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 倒着选择 DatFrame 全部
df[::-1]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-13</th>
#       <td>0.419350</td>
#       <td>1.062200</td>
#       <td>-0.554513</td>
#       <td>-0.217730</td>
#     </tr>
#     <tr>
#       <th>2017-07-12</th>
#       <td>0.173839</td>
#       <td>-0.232074</td>
#       <td>-0.030759</td>
#       <td>0.707334</td>
#     </tr>
#     <tr>
#       <th>2017-07-11</th>
#       <td>-0.704555</td>
#       <td>1.036348</td>
#       <td>-1.477565</td>
#       <td>0.945378</td>
#     </tr>
#     <tr>
#       <th>2017-07-10</th>
#       <td>-1.401200</td>
#       <td>0.677008</td>
#       <td>-2.046262</td>
#       <td>-1.787886</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>-1.673372</td>
#       <td>-0.673596</td>
#       <td>-0.711874</td>
#       <td>-0.976931</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>0.570197</td>
#       <td>0.545597</td>
#       <td>-0.815030</td>
#       <td>1.584542</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>0.648335</td>
#       <td>-1.008562</td>
#       <td>0.986980</td>
#       <td>1.136734</td>
#     </tr>
#     <tr>
#       <th>2017-07-06</th>
#       <td>-0.850651</td>
#       <td>-0.477734</td>
#       <td>-1.588885</td>
#       <td>0.245086</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### <font color="blue">2.2 使用 .loc 选择数据 (label)</font>

# %%
df1 = pd.DataFrame(np.random.randn(5, 4), columns=list('ABCD'), index=pd.date_range('20130101', periods=5))
df1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>2.031166</td>
#       <td>0.857202</td>
#       <td>1.336376</td>
#       <td>-1.050434</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>-1.110988</td>
#       <td>-0.286514</td>
#       <td>0.345784</td>
#       <td>-0.428011</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>0.313629</td>
#       <td>-0.092454</td>
#       <td>-0.143808</td>
#       <td>1.355029</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.281271</td>
#       <td>1.605933</td>
#       <td>-0.593882</td>
#       <td>0.072949</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>-0.039043</td>
#       <td>1.118500</td>
#       <td>0.073080</td>
#       <td>-0.005441</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 范围选择
df1['20130101':'20130104']
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>2.031166</td>
#       <td>0.857202</td>
#       <td>1.336376</td>
#       <td>-1.050434</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>-1.110988</td>
#       <td>-0.286514</td>
#       <td>0.345784</td>
#       <td>-0.428011</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>0.313629</td>
#       <td>-0.092454</td>
#       <td>-0.143808</td>
#       <td>1.355029</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.281271</td>
#       <td>1.605933</td>
#       <td>-0.593882</td>
#       <td>0.072949</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 不忘忘了加 loc，否则报错
df1.loc['20130101']
# Out:
# A    2.031166
# B    0.857202
# C    1.336376
# D   -1.050434
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# ### <font color="blue">2.3 使用 .iloc 选择数据</font>

# %% [markdown]
# ### <font color="blue">2.4 运算操作</font>
#
# Series 和 Numpy 有许多相似之处，对数据进行某个操作，不需要循环数据

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a   -0.764046
# b   -2.262633
# c   -0.942644
# d    0.944157
# e    0.279574
# dtype: float64

# %%
# 加法
s + s
# Out:
# a   -1.528092
# b   -4.525265
# c   -1.885288
# d    1.888314
# e    0.559147
# dtype: float64

# %%
# 乘法
s * 2
# Out:
# a   -1.528092
# b   -4.525265
# c   -1.885288
# d    1.888314
# e    0.559147
# dtype: float64

# %%
# 指数
np.exp(s)
# Out:
# a    0.465778
# b    0.104076
# c    0.389596
# d    2.570645
# e    1.322566
# dtype: float64

# %% [markdown]
# ## <font color="red"><h4 align="center">3. 属性</h4></font>

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20170706', periods=6), columns=list('ABCD'))

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-06', '2017-07-07', '2017-07-08', '2017-07-09',
#                '2017-07-10', '2017-07-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.84269724, -1.25975244, -1.27150604, -0.83574551],
#        [ 0.86408421, -0.96647416, -1.62552675, -0.69876559],
#        [-1.21609127, -0.93295903, -0.51131003,  0.49621801],
#        [ 2.84825352, -0.46590834, -0.52534091, -0.76890986],
#        [-0.78806923,  3.13891243, -1.68823267,  1.06075573],
#        [ 1.13531754,  0.60264649, -0.29922069, -2.54132751]])

# %% [markdown]
# ## <font color="red"><h4 align="center">4. 方法</h4></font>

# %%
maxvalue = df['Temperature'].max()
assert maxvalue == 50

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8]) # np.nan 表示 NaN, not a number
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# 以 numpy array 作为参数创建 `DataFrame`

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.081257</td>
#       <td>-0.583521</td>
#       <td>-0.956591</td>
#       <td>-1.150230</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.598011</td>
#       <td>0.044001</td>
#       <td>0.805043</td>
#       <td>-1.708032</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>0.497438</td>
#       <td>-0.879815</td>
#       <td>-1.790328</td>
#       <td>0.317809</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.080999</td>
#       <td>-0.991755</td>
#       <td>1.326935</td>
#       <td>-1.352318</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.016344</td>
#       <td>-0.033948</td>
#       <td>0.766915</td>
#       <td>1.387153</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>-0.036608</td>
#       <td>0.181089</td>
#       <td>0.460195</td>
#       <td>0.097629</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Creating a `DataFrame` by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo'})
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# A structured array
my_array = np.ones(3, dtype=([('foo', int), ('bar', float)]))
