# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Seaborn, 提供了 Matplotlib 的 high-level 接口，使 Matplotlib 的使用更容易。
#
# - [http://seaborn.pydata.org/tutorial.html](http://seaborn.pydata.org/tutorial.html)
# - [https://elitedatascience.com/python-seaborn-tutorial](https://elitedatascience.com/python-seaborn-tutorial)
# - [https://zhuanlan.zhihu.com/p/25737427](https://zhuanlan.zhihu.com/p/25737427)
# - [https://github.com/Hourout/seaborn.tutorial/blob/master/Seaborn_Tutorial_Distribution_plots%5B1%5Djointplot.ipynb](https://github.com/Hourout/seaborn.tutorial/blob/master/Seaborn_Tutorial_Distribution_plots%5B1%5Djointplot.ipynb)

# %%
## Read dataset
df = pd.read_csv('data/Pokemon.csv', index_col=0)

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Stage</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>#</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Bulbasaur</td>
# ...

# %%
sns.lmplot(x='Attack', y='Defense', data=df)

# %%
sns.lmplot(x='Attack', y='Defense', data=df, 
           fit_reg=False, # No regression line
           hue='Stage') #color by evolution state

# %% [markdown]
# 大多时候，使用 Seaborn 的API就可以，不过某些操作，必须使用 Matplotlib，例如，设置坐标轴范围：

# %%
# Plot using Seaborn
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue='Stage')

# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0, 142.26656605201049)

# %% [markdown]
# Seaborn 数据底层采用了 Pandas

# %%
# Boxplot
sns.boxplot(data=df)

# %% [markdown]
# ## Seaborn theme
#
# 默认主题为 'darkgrid'.

# %%
# set theme
sns.set_style('whitegrid')

# violin plot
sns.violinplot(x='Type 1', y='Attack', data=df)

# %%
# 修改上面的颜色
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                    ]
sns.violinplot(x='Type 1', y='Attack', data=df, palette=pkmn_type_colors)

# %% [markdown]
# Violin plots 用于可视化分布很好。
#
# 不过不适合用于显示所有数据。

# %%
# Swam plot with Pokemon color palette
sns.swarmplot(x='Type 1', y='Attack', data=df, palette=pkmn_type_colors)

# %% [markdown]
# ## Overlaying plots

# %% [markdown]
# 和 Matplotlib 一样简单

# %%
# Set figure size with matplotlib
plt.figure(figsize=(10, 6))

# Create plot
sns.violinplot(x='Type 1',
               y = 'Attack',
               data=df,
               inner=None, # Remove the bars inside the violins
               palette=pkmn_type_colors)
sns.swarmplot(x = 'Type 1',
              y='Attack',
              data=df,
              color='k', # Make points black
              alpha=0.7) # slightly transparent
# set title with Matplotlib
plt.title("Attach by Type")

# %% [markdown]
# 初始化 figure，但是不绘制任意 plot

# %%
sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
