# %% [markdown]
# # 1. 数据类型

# %%
import numpy as np
import pandas as pd

s1 = pd.Series(np.random.randn(5), index=list(range(0, 10, 2)))

# %%
df1 = pd.DataFrame(np.random.randn(5, 2), columns=list('AB'))

# %%
df1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.141845</td>
#       <td>0.219524</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.625948</td>
#       <td>0.257055</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.206109</td>
#       <td>-1.118508</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.179715</td>
#       <td>-0.028381</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.533245</td>
#       <td>0.303698</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s1.iloc[:3]
# Out:
# 0   -1.663384
# 2    1.616872
# 4   -0.541021
# dtype: float64

# %%
df = pd.DataFrame()

# %%
# 所有列的索引
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
# 输出所有的columns,为属性值
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
# 输出所有的值
df2.values
# Out:
# array([[1.0, Timestamp('2017-07-06 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2017-07-06 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2017-07-06 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2017-07-06 00:00:00'), 1.0, 3, 'train', 'foo']], dtype=object)

# %%
# 将 df2当做矩阵，然后转置一下
df2.T
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>2017-07-06 00:00:00</td>
#       <td>2017-07-06 00:00:00</td>
#       <td>2017-07-06 00:00:00</td>
#       <td>2017-07-06 00:00:00</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
# ...

# %%
# axis=1，对行的index进行排序
df2.sort_index(axis=1, ascending=False)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>F</th>
#       <th>E</th>
#       <th>D</th>
#       <th>C</th>
#       <th>B</th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>test</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>foo</td>
#       <td>train</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>test</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>2017-07-06</td>
# ...

# %%
# axis=0，对行的index进行排序
df2.sort_index(axis=0, ascending=False)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
# ...

# %%
# 对指定列的值进行排序
df2.sort_values(by='E')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2017-07-06</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
# ...

# %% [markdown]
# ##选择数据

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170706', periods=6)
df = pd.DataFrame(np.arange(24).reshape((6, 4)), index=dates, columns=['A','B','C','D'])
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#     </tr>
#     <tr>
# ...

# %%
# 还可以选择纵向标签
df.loc[:,['A', 'B']]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-07-06</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2017-07-07</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2017-07-08</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2017-07-09</th>
#       <td>12</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2017-07-10</th>
#       <td>16</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2017-07-11</th>
#       <td>20</td>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
# 选择特定行和特定列
df.loc["20170708", ['A', 'B']]
# Out:
# A    8
# B    9
# Name: 2017-07-08 00:00:00, dtype: int32

# %%
# 选择特定的行和列,这儿选择第三行数据
df.iloc[3]
# Out:
# A    12
# B    13
# C    14
# D    15
# Name: 2017-07-09 00:00:00, dtype: int32

# %%
# 第三行第一列
df.iloc[3, 1]
# Out:
# 13

# %% [markdown]
# 上面定义的为二维数据，所以我们用 `DataFrame` 对象存储。

# %%
df = pd.DataFrame(data=BabyDataSet, columns=['Names', 'Births'])
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Births</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>968</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jessica</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Mary</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>John</td>
#       <td>578</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# 将 `DataFrame` 导出为 **csv** 文件，使用 **`to_csv`** 函数。
#
# `Series` 和 `DataFrame` 包含 `to_csv`方法，可以将其数据导出为 csv 文件。该方法包含多个参数，具体可以参考文档，只有输出文件路径是必须的。
# - index: 是否输出行号，默认为 True
# - header: 是否输出column 名，默认为 True

# %%
loc = 'births1880.csv'
df.to_csv(loc, index=False, header=False)

# %% [markdown]
# ## 1.2 读取数据

# %% [markdown]
# `read_csv` 和 `read_table()` 是 pandas 提供的两个用于读取纯文本数据的函数。它俩使用相同的解析代码将表格数据转换为 `DataFrame` 对象。

# %%
df = pd.read_csv(loc)
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bob</th>
#       <th>968</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Jessica</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mary</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>John</td>
#       <td>578</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# `read_csv` 默认将第一行当做标题，需要修改一下：

# %%
df = pd.read_csv(loc, header=None)
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>968</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jessica</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Mary</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>John</td>
#       <td>578</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# 还可以在读取时赋予其标题行：

# %%
df = pd.read_csv(loc, names=['Names', 'Births'])
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Births</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bob</td>
#       <td>968</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jessica</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Mary</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>John</td>
#       <td>578</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# 把前面生成的 csv 文件删除，下面用不着了

# %%
import os
os.remove(loc)

# %% [markdown]
# ## 1.3 分析数据

# %%
# 查看数据类型
df.dtypes
# Out:
# Names     object
# Births     int64
# dtype: object

# %%
# 查看特定列的数据类型
df.Births.dtype
# Out:
# dtype('int64')

# %% [markdown]
# 找到最流行的名字，即对应的人数最多，我们可以这么干：
# - 将 `dataframe` 排序，然后第一行
# - 使用 `max()` 属性，找到最大值

# %%
# 方法1
Sorted = df.sort_values(['Births'], ascending=False)
Sorted.head(1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Births</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 方法2
df['Births'].max()
# Out:
# 973

# %% [markdown]
# ## 1.4 展示数据
#
# 使用图形展示，能更加直观看到数据的总体质量和分布。
#
# 代码解释：
# - `df['Names']`, 所有的婴儿名，即返回 'Names'这一列的所有值
# - `df['Births'].max()`, Births 列的最大值
# - `[df['Births'] == df['Births'].max()]`, 找到所有Births值为最大值(973)的行
# - `df['Names'][df['Births'] == df['Births'].max()]`, 选择所有 Births 值为973的行

# %%
# create graph
df['Births'].plot()

# Maximum value in the data set
MaxValue = df['Births'].max()

# Name associated with the maximum value
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

# Text to display on graph
Text = str(MaxValue) + '-' + MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular name")
df[df['Births'] == df['Births'].max()]
#Sorted.head(1) can also be used
# Out:
# The most popular name
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Births</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Mel</td>
#       <td>973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # IO 部分

# %% [markdown]
# ## Excel 读写
#
# **`read_excel`**
#
# 使用 `xlrd` 模块读取 Excel 2003 (.xls) 和 Excel 2007+(.xlsx) 格式文件。
# 参数列表
# parse_cols:
#
# - `to_excel()` 将 `DataFrame` 保存为 Excel。

# %%
loc = r'src/files/psm.xlsx'
df = pd.read_excel(loc, sheetname='Sheet1')
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>prot_acc</th>
#       <th>prot_desc</th>
#       <th>prot_score</th>
#       <th>prot_mass</th>
#       <th>prot_matches</th>
#       <th>prot_matches_sig</th>
#       <th>prot_sequences</th>
#       <th>prot_sequences_sig</th>
#       <th>pep_query</th>
#       <th>pep_rank</th>
#       <th>...</th>
#       <th>pep_exp_mz</th>
#       <th>pep_exp_mr</th>
#       <th>pep_exp_z</th>
#       <th>pep_calc_mr</th>
#       <th>pep_delta</th>
#       <th>pep_miss</th>
#       <th>pep_score</th>
#       <th>pep_expect</th>
#       <th>pep_res_before</th>
#       <th>pep_seq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
xlsx = pd.ExcelFile('path_to_file.xls')
df = pd.read_excel(xlsx, 'Sheet1')
